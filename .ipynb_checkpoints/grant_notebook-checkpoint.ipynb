# %%
import pyspark as ps
from pyspark.sql.functions import *

spark = (ps.sql.SparkSession.builder 
        .master("local[4]") 
        .appName("rec case study") 
        .getOrCreate()
        )

sc = spark.sparkContext

# %%
links = spark.read.csv('data/ml-latest-small/links.csv', header=True)
movies = spark.read.csv('data/ml-latest-small/movies.csv', header=True)
ratings = spark.read.csv('data/ml-latest-small/ratings.csv', header=True)
tags = spark.read.csv('data/ml-latest-small/tags.csv', header=True)

# %%
links.show(5)
print(links.count())
# Out:
# +-------+-------+------+
# |movieId| imdbId|tmdbId|
# +-------+-------+------+
# |      1|0114709|   862|
# |      2|0113497|  8844|
# |      3|0113228| 15602|
# |      4|0114885| 31357|
# |      5|0113041| 11862|
# +-------+-------+------+
# only showing top 5 rows
#
# 9742

# %%
movies.show(5)
print(movies.count())
# Out:
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |      1|    Toy Story (1995)|Adventure|Animati...|
# |      2|      Jumanji (1995)|Adventure|Childre...|
# |      3|Grumpier Old Men ...|      Comedy|Romance|
# |      4|Waiting to Exhale...|Comedy|Drama|Romance|
# |      5|Father of the Bri...|              Comedy|
# +-------+--------------------+--------------------+
# only showing top 5 rows
#
# 9742

# %%
ratings.show(5)
print(ratings.count())
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# +------+-------+------+---------+
# only showing top 5 rows
#
# 100836

# %%
tags.show(15)
print(tags.count())
# Out:
# +------+-------+-----------------+----------+
# |userId|movieId|              tag| timestamp|
# +------+-------+-----------------+----------+
# |     2|  60756|            funny|1445714994|
# |     2|  60756|  Highly quotable|1445714996|
# |     2|  60756|     will ferrell|1445714992|
# |     2|  89774|     Boxing story|1445715207|
# |     2|  89774|              MMA|1445715200|
# |     2|  89774|        Tom Hardy|1445715205|
# |     2| 106782|            drugs|1445715054|
# |     2| 106782|Leonardo DiCaprio|1445715051|
# |     2| 106782|  Martin Scorsese|1445715056|
# |     7|  48516|     way too long|1169687325|
# |    18|    431|        Al Pacino|1462138765|
# |    18|    431|         gangster|1462138749|
# |    18|    431|            mafia|1462138755|
# |    18|   1221|        Al Pacino|1461699306|
# |    18|   1221|            Mafia|1461699303|
# +------+-------+-----------------+----------+
# only showing top 15 rows
#
# 3683

# %%
total= movies.join(tags,movies("movieId") ==  tags("movieId"),"inner")
total.show(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7618d634b170> in <module>
# ----> 1 total= movies.join(tags,movies("movieId") ==  tags("movieId"),"inner")
#       2 total.show(5)
#
# TypeError: 'DataFrame' object is not callable

# %%
inner_join = movies.join(tags, movies.movieId == tags.movieId, "outer")
inner_join.show(15)
# Out:
# +-------+--------------------+--------------------+------+-------+-------+----------+
# |movieId|               title|              genres|userId|movieId|    tag| timestamp|
# +-------+--------------------+--------------------+------+-------+-------+----------+
# | 100553|Frozen Planet (2011)|         Documentary|  null|   null|   null|      null|
# | 102684|Only God Forgives...|      Drama|Thriller|  null|   null|   null|      null|
# |   1090|      Platoon (1986)|           Drama|War|   474|   1090|Vietnam|1138137990|
# | 112911|     Hercules (2014)|    Action|Adventure|  null|   null|   null|      null|
# | 115713|   Ex Machina (2015)|Drama|Sci-Fi|Thri...|  null|   null|   null|      null|
# | 117630|Double Trouble (1...|Action|Comedy|Cri...|  null|   null|   null|      null|
# | 119655|  Seventh Son (2014)|Adventure|Childre...|  null|   null|   null|      null|
# | 120478|The Salt of the E...|         Documentary|  null|   null|   null|      null|
# | 121007|Space Buddies (2009)|Adventure|Childre...|  null|   null|   null|      null|
# |   1572|Contempt (Mépris,...|               Drama|  null|   null|   null|      null|
# | 158813|Alice Through the...|Adventure|Childre...|  null|   null|   null|      null|
# | 173535|The Adventures of...|  (no genres listed)|  null|   null|   null|      null|
# |   2069|Trip to Bountiful...|               Drama|  null|   null|   null|      null|
# |   2088|       Popeye (1980)|Adventure|Comedy|...|  null|   null|   null|      null|
# |   2136|Nutty Professor, ...|       Comedy|Sci-Fi|  null|   null|   null|      null|
# +-------+--------------------+--------------------+------+-------+-------+----------+
# only showing top 15 rows

# %%
mov_tag_join = movies.join(tags, ["movieId"], "outer")

mov_tag_join.show(15)
# Out:
# +-------+--------------------+--------------------+------+-------+----------+
# |movieId|               title|              genres|userId|    tag| timestamp|
# +-------+--------------------+--------------------+------+-------+----------+
# | 100553|Frozen Planet (2011)|         Documentary|  null|   null|      null|
# | 102684|Only God Forgives...|      Drama|Thriller|  null|   null|      null|
# |   1090|      Platoon (1986)|           Drama|War|   474|Vietnam|1138137990|
# | 112911|     Hercules (2014)|    Action|Adventure|  null|   null|      null|
# | 115713|   Ex Machina (2015)|Drama|Sci-Fi|Thri...|  null|   null|      null|
# | 117630|Double Trouble (1...|Action|Comedy|Cri...|  null|   null|      null|
# | 119655|  Seventh Son (2014)|Adventure|Childre...|  null|   null|      null|
# | 120478|The Salt of the E...|         Documentary|  null|   null|      null|
# | 121007|Space Buddies (2009)|Adventure|Childre...|  null|   null|      null|
# |   1572|Contempt (Mépris,...|               Drama|  null|   null|      null|
# | 158813|Alice Through the...|Adventure|Childre...|  null|   null|      null|
# | 173535|The Adventures of...|  (no genres listed)|  null|   null|      null|
# |   2069|Trip to Bountiful...|               Drama|  null|   null|      null|
# |   2088|       Popeye (1980)|Adventure|Comedy|...|  null|   null|      null|
# |   2136|Nutty Professor, ...|       Comedy|Sci-Fi|  null|   null|      null|
# +-------+--------------------+--------------------+------+-------+----------+
# only showing top 15 rows

# %%
mov_tag_join.createOrReplaceTempView("first_df")
result = spark.sql('''
    SELECT movieId, userId, title, genres, tag
    FROM first_df
    ''')

result.show()

# df_f = result.toPandas()
# df_f
# Out:
# +-------+------+--------------------+--------------------+-------------+
# |movieId|userId|               title|              genres|          tag|
# +-------+------+--------------------+--------------------+-------------+
# | 100553|  null|Frozen Planet (2011)|         Documentary|         null|
# | 102684|  null|Only God Forgives...|      Drama|Thriller|         null|
# |   1090|   474|      Platoon (1986)|           Drama|War|      Vietnam|
# | 112911|  null|     Hercules (2014)|    Action|Adventure|         null|
# | 115713|  null|   Ex Machina (2015)|Drama|Sci-Fi|Thri...|         null|
# | 117630|  null|Double Trouble (1...|Action|Comedy|Cri...|         null|
# | 119655|  null|  Seventh Son (2014)|Adventure|Childre...|         null|
# | 120478|  null|The Salt of the E...|         Documentary|         null|
# | 121007|  null|Space Buddies (2009)|Adventure|Childre...|         null|
# |   1572|  null|Contempt (Mépris,...|               Drama|         null|
# | 158813|  null|Alice Through the...|Adventure|Childre...|         null|
# | 173535|  null|The Adventures of...|  (no genres listed)|         null|
# |   2069|  null|Trip to Bountiful...|               Drama|         null|
# |   2088|  null|       Popeye (1980)|Adventure|Comedy|...|         null|
# |   2136|  null|Nutty Professor, ...|       Comedy|Sci-Fi|         null|
# |   2162|  null|NeverEnding Story...|Adventure|Childre...|         null|
# |   2294|  null|         Antz (1998)|Adventure|Animati...|         null|
# |  26082|  null|Harakiri (Seppuku...|               Drama|         null|
# |  27317|  null|Audition (Ôdishon...|Drama|Horror|Myst...|         null|
# |    296|   103| Pulp Fiction (1994)|Comedy|Crime|Dram...|good dialogue|
# +-------+------+--------------------+--------------------+-------------+
# only showing top 20 rows

# %%
# mov_tag_rating_join = mov_tag_join.join(ratings, ["movieId"])

mov_tag_rating_join = mov_tag_join.join(ratings, ["movieId", 'userId'], 'outer')

mov_tag_rating_join.show()
print(mov_tag_rating_join.count())
# Out:
# +-------+------+--------------------+--------------------+--------------------+----------+------+----------+
# |movieId|userId|               title|              genres|                 tag| timestamp|rating| timestamp|
# +-------+------+--------------------+--------------------+--------------------+----------+------+----------+
# | 100553|  null|Frozen Planet (2011)|         Documentary|                null|      null|  null|      null|
# | 102684|  null|Only God Forgives...|      Drama|Thriller|                null|      null|  null|      null|
# |      1|   330|                null|                null|                null|      null|   4.0|1285904910|
# |    100|   207|                null|                null|                null|      null|   3.0|1258548270|
# | 101072|    50|                null|                null|                null|      null|   2.5|1514240485|
# | 101577|   448|                null|                null|                null|      null|   1.0|1399147624|
# | 102125|   210|                null|                null|                null|      null|   4.5|1527266096|
# | 102602|   105|                null|                null|                null|      null|   4.0|1446573183|
# |   1028|   469|                null|                null|                null|      null|   4.0| 965336236|
# |   1035|   448|                null|                null|                null|      null|   4.0|1019140874|
# |   1035|   474|Sound of Music, T...|     Musical|Romance|Rogers and Hammer...|1137181179|   5.0| 974666694|
# | 112911|  null|     Hercules (2014)|    Action|Adventure|                null|      null|  null|      null|
# | 115713|  null|   Ex Machina (2015)|Drama|Sci-Fi|Thri...|                null|      null|  null|      null|
# |   1036|   279|                null|                null|                null|      null|   5.0|1506394402|
# |   1036|   412|                null|                null|                null|      null|   3.0| 939114775|
# |   1036|   469|                null|                null|                null|      null|   4.0| 965333794|
# |   1036|   594|                null|                null|                null|      null|   5.0|1109036966|
# |    104|   356|                null|                null|                null|      null|   3.0|1232430472|
# | 104141|   380|                null|                null|                null|      null|   3.0|1536873818|
# |   1047|   544|                null|                null|                null|      null|   5.0| 850688776|
# +-------+------+--------------------+--------------------+--------------------+----------+------+----------+
# only showing top 20 rows
#
# 111054

# %%
mov_tag_rating_join.createOrReplaceTempView("second_df")
new_result = spark.sql('''
    SELECT userId, movieId, rating, title, genres, tag
    FROM second_df
    ''')

new_result.show()
# Out:
# +------+-------+------+--------------------+--------------------+--------------------+
# |userId|movieId|rating|               title|              genres|                 tag|
# +------+-------+------+--------------------+--------------------+--------------------+
# |  null| 100553|  null|Frozen Planet (2011)|         Documentary|                null|
# |  null| 102684|  null|Only God Forgives...|      Drama|Thriller|                null|
# |   330|      1|   4.0|                null|                null|                null|
# |   207|    100|   3.0|                null|                null|                null|
# |    50| 101072|   2.5|                null|                null|                null|
# |   448| 101577|   1.0|                null|                null|                null|
# |   210| 102125|   4.5|                null|                null|                null|
# |   105| 102602|   4.0|                null|                null|                null|
# |   469|   1028|   4.0|                null|                null|                null|
# |   448|   1035|   4.0|                null|                null|                null|
# |   474|   1035|   5.0|Sound of Music, T...|     Musical|Romance|Rogers and Hammer...|
# |  null| 112911|  null|     Hercules (2014)|    Action|Adventure|                null|
# |  null| 115713|  null|   Ex Machina (2015)|Drama|Sci-Fi|Thri...|                null|
# |   279|   1036|   5.0|                null|                null|                null|
# |   412|   1036|   3.0|                null|                null|                null|
# |   469|   1036|   4.0|                null|                null|                null|
# |   594|   1036|   5.0|                null|                null|                null|
# |   356|    104|   3.0|                null|                null|                null|
# |   380| 104141|   3.0|                null|                null|                null|
# |   544|   1047|   5.0|                null|                null|                null|
# +------+-------+------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
full_join = mov_tag_rating_join.join(links, ["movieId"], 'outer')

full_join.show()
print(full_join.count())
# Out:
# +-------+------+--------------------+--------------+-------+----------+------+----------+-------+------+
# |movieId|userId|               title|        genres|    tag| timestamp|rating| timestamp| imdbId|tmdbId|
# +-------+------+--------------------+--------------+-------+----------+------+----------+-------+------+
# | 100553|  null|Frozen Planet (2011)|   Documentary|   null|      null|  null|      null|2092588|134481|
# | 100553|   105|                null|          null|   null|      null|   4.5|1446572398|2092588|134481|
# | 100553|   318|                null|          null|   null|      null|   4.5|1426353247|2092588|134481|
# | 102684|  null|Only God Forgives...|Drama|Thriller|   null|      null|  null|      null|1602613| 77987|
# | 102684|   380|                null|          null|   null|      null|   4.0|1494709199|1602613| 77987|
# | 102684|   249|                null|          null|   null|      null|   3.5|1376654552|1602613| 77987|
# |   1090|   372|                null|          null|   null|      null|   4.0| 874416661|0091763|   792|
# |   1090|   384|                null|          null|   null|      null|   4.0| 994038103|0091763|   792|
# |   1090|   474|      Platoon (1986)|     Drama|War|Vietnam|1138137990|   3.5|1118667194|0091763|   792|
# |   1090|   577|                null|          null|   null|      null|   3.0| 945966476|0091763|   792|
# |   1090|   140|                null|          null|   null|      null|   4.0|1055092338|0091763|   792|
# |   1090|    59|                null|          null|   null|      null|   4.0| 953610028|0091763|   792|
# |   1090|   266|                null|          null|   null|      null|   5.0| 944891645|0091763|   792|
# |   1090|   305|                null|          null|   null|      null|   5.0|1462397928|0091763|   792|
# |   1090|   218|                null|          null|   null|      null|   3.0|1111624837|0091763|   792|
# |   1090|   516|                null|          null|   null|      null|   3.0| 994625023|0091763|   792|
# |   1090|   419|                null|          null|   null|      null|   4.0|1321766180|0091763|   792|
# |   1090|   368|                null|          null|   null|      null|   5.0| 971273268|0091763|   792|
# |   1090|    84|                null|          null|   null|      null|   4.0| 858772239|0091763|   792|
# |   1090|   202|                null|          null|   null|      null|   5.0| 974912698|0091763|   792|
# +-------+------+--------------------+--------------+-------+----------+------+----------+-------+------+
# only showing top 20 rows
#
# 111054

# %%
full_join.createOrReplaceTempView("third_df")
final_result = spark.sql('''
    SELECT userId, movieId, rating, title, genres, tag, imdbId, tmdbId
    FROM third_df
    ''')

final_result.show()
# Out:
# +------+-------+------+--------------------+--------------+-------+-------+------+
# |userId|movieId|rating|               title|        genres|    tag| imdbId|tmdbId|
# +------+-------+------+--------------------+--------------+-------+-------+------+
# |  null| 100553|  null|Frozen Planet (2011)|   Documentary|   null|2092588|134481|
# |   105| 100553|   4.5|                null|          null|   null|2092588|134481|
# |   318| 100553|   4.5|                null|          null|   null|2092588|134481|
# |  null| 102684|  null|Only God Forgives...|Drama|Thriller|   null|1602613| 77987|
# |   380| 102684|   4.0|                null|          null|   null|1602613| 77987|
# |   249| 102684|   3.5|                null|          null|   null|1602613| 77987|
# |   372|   1090|   4.0|                null|          null|   null|0091763|   792|
# |   384|   1090|   4.0|                null|          null|   null|0091763|   792|
# |   474|   1090|   3.5|      Platoon (1986)|     Drama|War|Vietnam|0091763|   792|
# |   577|   1090|   3.0|                null|          null|   null|0091763|   792|
# |   140|   1090|   4.0|                null|          null|   null|0091763|   792|
# |    59|   1090|   4.0|                null|          null|   null|0091763|   792|
# |   266|   1090|   5.0|                null|          null|   null|0091763|   792|
# |   305|   1090|   5.0|                null|          null|   null|0091763|   792|
# |   218|   1090|   3.0|                null|          null|   null|0091763|   792|
# |   516|   1090|   3.0|                null|          null|   null|0091763|   792|
# |   419|   1090|   4.0|                null|          null|   null|0091763|   792|
# |   368|   1090|   5.0|                null|          null|   null|0091763|   792|
# |    84|   1090|   4.0|                null|          null|   null|0091763|   792|
# |   202|   1090|   5.0|                null|          null|   null|0091763|   792|
# +------+-------+------+--------------------+--------------+-------+-------+------+
# only showing top 20 rows

# %%
full_df = final_result.toPandas()

full_df
# Out:
#        userId movieId rating                     title               genres  \
# 0        None  100553   None      Frozen Planet (2011)          Documentary
# 1         105  100553    4.5                      None                 None
# 2         318  100553    4.5                      None                 None
# 3        None  102684   None  Only God Forgives (2013)       Drama|Thriller
# 4         380  102684    4.0                      None                 None
# ...       ...     ...    ...                       ...                  ...
# 111049    414   96610    4.5                      None                 None
# 111050    331   96610    3.5                      None                 None
# 111051    582   96610    2.5                      None                 None
# 111052    256   96610    4.0                      None                 None
# 111053   None   96610   None             Looper (2012)  Action|Crime|Sci-Fi
#
#          tag   imdbId  tmdbId
# 0       None  2092588  134481
# 1       None  2092588  134481
# 2       None  2092588  134481
# 3       None  1602613   77987
# 4       None  1602613   77987
# ...      ...      ...     ...
# 111049  None  1276104   59967
# 111050  None  1276104   59967
# 111051  None  1276104   59967
# 111052  None  1276104   59967
# 111053  None  1276104   59967
#
# [111054 rows x 8 columns]

# %%
# full_df['genres'] = full_df['genres'].map(lambda x: x.lstrip('+-').rstrip('aAbBcC'))

full_df['genres'] = full_df['genres'].str.replace('|', ' ')

full_df.head()
# Out:
#   userId movieId rating                     title          genres   tag  \
# 0   None  100553   None      Frozen Planet (2011)     Documentary  None
# 1    105  100553    4.5                      None            None  None
# 2    318  100553    4.5                      None            None  None
# 3   None  102684   None  Only God Forgives (2013)  Drama Thriller  None
# 4    380  102684    4.0                      None            None  None
#
#     imdbId  tmdbId
# 0  2092588  134481
# 1  2092588  134481
# 2  2092588  134481
# 3  1602613   77987
# 4  1602613   77987

# %% [markdown]
# ## Trying Again

# %%
rating_tag_join = ratings.join(tags, ["movieId", 'userId'], "left")

rating_tag_join.show()
print(rating_tag_join.count())
# Out:
# +-------+------+------+---------+----+---------+
# |movieId|userId|rating|timestamp| tag|timestamp|
# +-------+------+------+---------+----+---------+
# |      1|     1|   4.0|964982703|null|     null|
# |      3|     1|   4.0|964981247|null|     null|
# |      6|     1|   4.0|964982224|null|     null|
# |     47|     1|   5.0|964983815|null|     null|
# |     50|     1|   5.0|964982931|null|     null|
# |     70|     1|   3.0|964982400|null|     null|
# |    101|     1|   5.0|964980868|null|     null|
# |    110|     1|   4.0|964982176|null|     null|
# |    151|     1|   5.0|964984041|null|     null|
# |    157|     1|   5.0|964984100|null|     null|
# |    163|     1|   5.0|964983650|null|     null|
# |    216|     1|   5.0|964981208|null|     null|
# |    223|     1|   3.0|964980985|null|     null|
# |    231|     1|   5.0|964981179|null|     null|
# |    235|     1|   4.0|964980908|null|     null|
# |    260|     1|   5.0|964981680|null|     null|
# |    296|     1|   3.0|964982967|null|     null|
# |    316|     1|   3.0|964982310|null|     null|
# |    333|     1|   5.0|964981179|null|     null|
# |    349|     1|   4.0|964982563|null|     null|
# +-------+------+------+---------+----+---------+
# only showing top 20 rows
#
# 102677

# %%
rating_tag_join.createOrReplaceTempView("dfone")
first = spark.sql('''
    SELECT userId, movieId, rating, tag
    FROM dfone
    ''')

first.show(50)
# Out:
# +------+-------+------+----+
# |userId|movieId|rating| tag|
# +------+-------+------+----+
# |     1|      1|   4.0|null|
# |     1|      3|   4.0|null|
# |     1|      6|   4.0|null|
# |     1|     47|   5.0|null|
# |     1|     50|   5.0|null|
# |     1|     70|   3.0|null|
# |     1|    101|   5.0|null|
# |     1|    110|   4.0|null|
# |     1|    151|   5.0|null|
# |     1|    157|   5.0|null|
# |     1|    163|   5.0|null|
# |     1|    216|   5.0|null|
# |     1|    223|   3.0|null|
# |     1|    231|   5.0|null|
# |     1|    235|   4.0|null|
# |     1|    260|   5.0|null|
# |     1|    296|   3.0|null|
# |     1|    316|   3.0|null|
# |     1|    333|   5.0|null|
# |     1|    349|   4.0|null|
# |     1|    356|   4.0|null|
# |     1|    362|   5.0|null|
# |     1|    367|   4.0|null|
# |     1|    423|   3.0|null|
# |     1|    441|   4.0|null|
# |     1|    457|   5.0|null|
# |     1|    480|   4.0|null|
# |     1|    500|   3.0|null|
# |     1|    527|   5.0|null|
# |     1|    543|   4.0|null|
# |     1|    552|   4.0|null|
# |     1|    553|   5.0|null|
# |     1|    590|   4.0|null|
# |     1|    592|   4.0|null|
# |     1|    593|   4.0|null|
# |     1|    596|   5.0|null|
# |     1|    608|   5.0|null|
# |     1|    648|   3.0|null|
# |     1|    661|   5.0|null|
# |     1|    673|   3.0|null|
# |     1|    733|   4.0|null|
# |     1|    736|   3.0|null|
# |     1|    780|   3.0|null|
# |     1|    804|   4.0|null|
# |     1|    919|   5.0|null|
# |     1|    923|   5.0|null|
# |     1|    940|   5.0|null|
# |     1|    943|   4.0|null|
# |     1|    954|   5.0|null|
# |     1|   1009|   3.0|null|
# +------+-------+------+----+
# only showing top 50 rows

# %%
rating_tag_movies_join = first.join(movies, ["movieId"], "left")

rating_tag_movies_join.show()
print(rating_tag_movies_join.count())
# Out:
# +-------+------+------+----+--------------------+--------------------+
# |movieId|userId|rating| tag|               title|              genres|
# +-------+------+------+----+--------------------+--------------------+
# |      1|     1|   4.0|null|    Toy Story (1995)|Adventure|Animati...|
# |      3|     1|   4.0|null|Grumpier Old Men ...|      Comedy|Romance|
# |      6|     1|   4.0|null|         Heat (1995)|Action|Crime|Thri...|
# |     47|     1|   5.0|null|Seven (a.k.a. Se7...|    Mystery|Thriller|
# |     50|     1|   5.0|null|Usual Suspects, T...|Crime|Mystery|Thr...|
# |     70|     1|   3.0|null|From Dusk Till Da...|Action|Comedy|Hor...|
# |    101|     1|   5.0|null|Bottle Rocket (1996)|Adventure|Comedy|...|
# |    110|     1|   4.0|null|   Braveheart (1995)|    Action|Drama|War|
# |    151|     1|   5.0|null|      Rob Roy (1995)|Action|Drama|Roma...|
# |    157|     1|   5.0|null|Canadian Bacon (1...|          Comedy|War|
# |    163|     1|   5.0|null|    Desperado (1995)|Action|Romance|We...|
# |    216|     1|   5.0|null|Billy Madison (1995)|              Comedy|
# |    223|     1|   3.0|null|       Clerks (1994)|              Comedy|
# |    231|     1|   5.0|null|Dumb & Dumber (Du...|    Adventure|Comedy|
# |    235|     1|   4.0|null|      Ed Wood (1994)|        Comedy|Drama|
# |    260|     1|   5.0|null|Star Wars: Episod...|Action|Adventure|...|
# |    296|     1|   3.0|null| Pulp Fiction (1994)|Comedy|Crime|Dram...|
# |    316|     1|   3.0|null|     Stargate (1994)|Action|Adventure|...|
# |    333|     1|   5.0|null|    Tommy Boy (1995)|              Comedy|
# |    349|     1|   4.0|null|Clear and Present...|Action|Crime|Dram...|
# +-------+------+------+----+--------------------+--------------------+
# only showing top 20 rows
#
# 102677

# %%
rating_tag_movies_links_join = rating_tag_movies_join.join(links, ["movieId"], "left")

rating_tag_movies_links_join.show(5)
print(rating_tag_movies_links_join.count())
# Out:
# +-------+------+------+----+--------------------+--------------------+-------+------+
# |movieId|userId|rating| tag|               title|              genres| imdbId|tmdbId|
# +-------+------+------+----+--------------------+--------------------+-------+------+
# |      1|     1|   4.0|null|    Toy Story (1995)|Adventure|Animati...|0114709|   862|
# |      3|     1|   4.0|null|Grumpier Old Men ...|      Comedy|Romance|0113228| 15602|
# |      6|     1|   4.0|null|         Heat (1995)|Action|Crime|Thri...|0113277|   949|
# |     47|     1|   5.0|null|Seven (a.k.a. Se7...|    Mystery|Thriller|0114369|   807|
# |     50|     1|   5.0|null|Usual Suspects, T...|Crime|Mystery|Thr...|0114814|   629|
# +-------+------+------+----+--------------------+--------------------+-------+------+
# only showing top 5 rows
#
# 102677

# %%
final_df = rating_tag_movies_links_join.toPandas()

final_df
# Out:
#        movieId userId rating               tag  \
# 0            1      1    4.0              None
# 1            3      1    4.0              None
# 2            6      1    4.0              None
# 3           47      1    5.0              None
# 4           50      1    5.0              None
# ...        ...    ...    ...               ...
# 102672  166534    610    4.0              None
# 102673  168248    610    5.0  Heroic Bloodshed
# 102674  168250    610    5.0              None
# 102675  168252    610    5.0              None
# 102676  170875    610    3.0              None
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 102672                    Split (2017)
# 102673   John Wick: Chapter Two (2017)
# 102674                  Get Out (2017)
# 102675                    Logan (2017)
# 102676  The Fate of the Furious (2017)
#
#                                              genres   imdbId  tmdbId
# 0       Adventure|Animation|Children|Comedy|Fantasy  0114709     862
# 1                                    Comedy|Romance  0113228   15602
# 2                             Action|Crime|Thriller  0113277     949
# 3                                  Mystery|Thriller  0114369     807
# 4                            Crime|Mystery|Thriller  0114814     629
# ...                                             ...      ...     ...
# 102672                        Drama|Horror|Thriller  4972582  381288
# 102673                        Action|Crime|Thriller  4425200  324552
# 102674                                       Horror  5052448  419430
# 102675                                Action|Sci-Fi  3315342  263115
# 102676                  Action|Crime|Drama|Thriller  4630562  337339
#
# [102677 rows x 8 columns]

# %%
final_df['genres'] = final_df['genres'].str.replace('|', ' ')

final_df.head()
# Out:
#   movieId userId rating   tag                        title  \
# 0       1      1    4.0  None             Toy Story (1995)
# 1       3      1    4.0  None      Grumpier Old Men (1995)
# 2       6      1    4.0  None                  Heat (1995)
# 3      47      1    5.0  None  Seven (a.k.a. Se7en) (1995)
# 4      50      1    5.0  None   Usual Suspects, The (1995)
#
#                                         genres   imdbId tmdbId
# 0  Adventure Animation Children Comedy Fantasy  0114709    862
# 1                               Comedy Romance  0113228  15602
# 2                        Action Crime Thriller  0113277    949
# 3                             Mystery Thriller  0114369    807
# 4                       Crime Mystery Thriller  0114814    629
